# %% [markdown]
# ### !!!

# %%
# !pip install transformers datasets

# %%
import pandas as pd

splits = {'train': 'full/train-00000-of-00001.parquet', 'test': 'full/test-00000-of-00001.parquet', 'validation': 'full/validation-00000-of-00001.parquet', 'prompt': 'full/prompt-00000-of-00001.parquet'}
mbpp_df = pd.read_parquet("hf://datasets/google-research-datasets/mbpp/" + splits["train"])

# %%
mbpp_df
# Out:
#      task_id                                               text  \
# 0        601  Write a function to find the longest chain whi...
# 1        602  Write a python function to find the first repe...
# 2        603  Write a function to get a lucid number smaller...
# 3        604  Write a function to reverse words in a given s...
# 4        605  Write a function to check if the given integer...
# ..       ...                                                ...
# 369      970   Write a function to find minimum of two numbers.
# 370      971  Write a function to find the maximum number of...
# 371      972  Write a function to concatenate the given two ...
# 372      973  Write a python function to left rotate the str...
# 373      974  Write a function to find the minimum total pat...
#
#                                                   code  \
# 0    class Pair(object): \r\n\tdef __init__(self, a...
# 1    def first_repeated_char(str1):\r\n  for index,...
# ...

# %%
import os
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ### Load Dataset

# %%
from datasets import load_dataset

# %%
ds = load_dataset("codeparrot/apps")

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['problem_id', 'question', 'solutions', 'input_output', 'difficulty', 'url', 'starter_code'],
#         num_rows: 5000
#     })
#     test: Dataset({
#         features: ['problem_id', 'question', 'solutions', 'input_output', 'difficulty', 'url', 'starter_code'],
#         num_rows: 5000
#     })
# })

# %%
train_dataset = ds["train"]
df = train_dataset.to_pandas()
df
# Out:
#       problem_id                                           question  \
# 0              0  Polycarp has $n$ different binary words. A wor...
# 1              1  Mikhail walks on a Cartesian plane. He starts ...
# 2              2  You are given three sequences: $a_1, a_2, \ldo...
# 3              3  You have $n$ barrels lined up in a row, number...
# 4              4  You are given a permutation $p=[p_1, p_2, \ldo...
# ...          ...                                                ...
# 4995        4995  Another rewarding day in the fast-paced world ...
# 4996        4996  ## **Instructions**\n\nThe goal of this kata i...
# 4997        4997  The function sigma 1, σ1 in mathematics, is kn...
# 4998        4998  The principal of a school likes to put challen...
# 4999        4999  Complete the method that takes a sequence of o...
#
#                                               solutions  \
# 0     ["for _ in range(int(input())):\n    n = int(i...
# ...

# %%
df.to_csv("train.csv", index = False)

# %%
from transformers import RobertaTokenizer

tokenizer = RobertaTokenizer.from_pretrained("Salesforce/codet5-base")

# %% [markdown]
# ### Preprocess the data

# %%
import cohere

# %%
cohere_api_key = '7DNoxjgNM7h9ffV8WGcQYPnsggQUUhq2UYywfk3Z'
co = cohere.Client(cohere_api_key)

# %%
def preprocessing(dataframe):
    responses = []
    model_name = "command-r-plus"
    for _, row in dataframe.iterrows():
        prompt = row["question"]
        task_id = row["problem_id"]
        solution = row["solutions"]
        try:
            generated_soln = co.generate(
                model=model_name,  
                prompt=prompt,
                temperature=0.7
            )
            responses.append(
                {
                    "task_id": task_id,
                    "prompt": prompt,
                    "solution": solution,
                    "generated_output": generated_soln
                }
            )
        except Exception as e:
            print(f"Error generating response for prompt: {task_id}\n{e}")
            responses.append(
                {
                    "task_id": task_id,
                    "prompt": prompt,
                    "solution": solution,
                    "generated_output": ""
                }
            )
    return responses

# %%
train_responses = preprocessing(df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 train_responses = preprocessing(df)
#
# Cell In[42], line 9, in preprocessing(dataframe)
#       7 solution = row["solutions"]
#       8 try:
# ----> 9     generated_soln = co.generate(
#      10         model=model_name,
#      11         prompt=prompt,
#      12         temperature=0.7
#      13     )
#      14     responses.append(
#      15         {
#      16             "task_id": task_id,
#    (...)
#      20         }
#      21     )
#      22 except Exception as e:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\cohere\base_client.py:1619, in BaseCohere.generate(self, prompt, model, num_generations, max_tokens, truncate, temperature, seed, preset, end_sequences, stop_sequences, k, p, frequency_penalty, presence_penalty, return_likelihoods, raw_prompting, request_options)
# ...

# %%
len(train_responses)
# Out:
# 5000

# %%
train_responses[0]
# Out:
# {'task_id': 0,
# ...

# %% [markdown]
# ### Gemini API

# %%
api_key = os.get(

# %%
# !pip install google-generativeai
# Out:
# ...
#    ---------------------------------------- 0.0/760.0 kB ? eta -:--:--
#    ------------- -------------------------- 262.1/760.0 kB ? eta -:--:--
#    ---------------------------------------- 760.0/760.0 kB 3.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.7 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.7 MB 1.9 MB/s eta 0:00:07
#    --- ------------------------------------ 1.0/12.7 MB 2.1 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.6/12.7 MB 2.2 MB/s eta 0:00:06
#    ------ --------------------------------- 2.1/12.7 MB 2.3 MB/s eta 0:00:05
#    -------- ------------------------------- 2.6/12.7 MB 2.4 MB/s eta 0:00:05
#    ---------- ----------------------------- 3.4/12.7 MB 2.6 MB/s eta 0:00:04
#    ------------- -------------------------- 4.2/12.7 MB 2.7 MB/s eta 0:00:04
# ...

# %%
import google.generativeai as genai
import os

genai.configure(api_key="AIzaSyCR9KSalZo60AOd93oPmJ9IHduoFpx4b1I")

model = genai.GenerativeModel('gemini-1.5-flash')
response = model.generate_content("The opposite of hot is")
print(response.text)
# Out:
# cold

# %%
def preprocessing(dataframe):
    responses = []
    model_name = "gemini-1.5-flash"
    for _, row in dataframe.iterrows():
        prompt = row["question"]
        task_id = row["problem_id"]
        solution = row["solutions"]
        try:
            generated_soln = model.generate_content(prompt)
            responses.append(
                {
                    "task_id": task_id,
                    "prompt": prompt,
                    "solution": solution,
                    "generated_output": generated_soln.text
                }
            )
            print(f"{task_id} done")
        except Exception as e:
            print(f"Error generating response for prompt: {task_id}\n{e}")
            responses.append(
                {
                    "task_id": task_id,
                    "prompt": prompt,
                    "solution": solution,
                    "generated_output": ""
                }
            )
    return responses

# %%
responses = []
import numpy as np
import pandas as pd

def split_dataframe(dataframe, batch_size):
    """
    Splits a DataFrame into smaller DataFrames of the specified batch size.

    Args:
        dataframe (pd.DataFrame): The DataFrame to split.
        batch_size (int): The number of rows per batch.

    Returns:
        List[pd.DataFrame]: A list of DataFrame batches.
    """
    num_batches = int(np.ceil(len(dataframe) / batch_size))
    return [dataframe.iloc[i * batch_size: (i + 1) * batch_size] for i in range(num_batches)]

batch_size = 10
batches = split_dataframe(df, batch_size)

# %%
batches[0]
# Out:
#    problem_id                                           question  \
# 0           0  Polycarp has $n$ different binary words. A wor...
# 1           1  Mikhail walks on a Cartesian plane. He starts ...
# 2           2  You are given three sequences: $a_1, a_2, \ldo...
# 3           3  You have $n$ barrels lined up in a row, number...
# 4           4  You are given a permutation $p=[p_1, p_2, \ldo...
# 5           5  The sequence of $m$ integers is called the per...
# 6           6  Arthur owns a ski resort on a mountain. There ...
# 7           7  The only difference between easy and hard vers...
# 8           8  You like playing chess tournaments online.\n\n...
# 9           9  Alice and Bob play a game. They have a binary ...
#
#                                            solutions  \
# 0  ["for _ in range(int(input())):\n    n = int(i...
# 1  ["q=int(input())\n\nfor e in range(q):\n    x,...
# 2  ["import sys\nimport random\nfrom fractions im...
# ...

# %%
batch_response = preprocessing(batches[0])
# Out:
# Error generating response for prompt: 0
# Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 4. Meaning that the model was reciting from copyrighted material.
# 1 done
# 2 done
# 3 done
# 4 done
# 5 done
# 6 done
# Error generating response for prompt: 7
# Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 4. Meaning that the model was reciting from copyrighted material.
# 8 done
# 9 done

# %%
generated_outputs = [
    response.get("generated_output") 
    for response in batch_response
    if "generated_output" in response
]
for i, output in enumerate(generated_outputs):
    print(f"Response {i+1}: {output}")
# Out:
# Response 1:
# Response 2: ```python
# def solve():
#     q = int(input())
#     for _ in range(q):
#         n, m, k = map(int, input().split())
#
#         max_dist = max(n, m)
#         min_dist = min(n, m)
#
#         if (n + m) > k or (k - (n + m)) % 2 != 0 or k < max_dist:
#             print(-1)
#             continue
#
#         diag = min_dist
#         rem_moves = k - (n + m)
#
#         rem_moves //= 2
#
#         diag += rem_moves
#         print(diag)
#
#
# solve()
# ```
# Response 3: ```python
# def solve():
#     n = int(input())
#     a = list(map(int, input().split()))
#     b = list(map(int, input().split()))
#     c = list(map(int, input().split()))
#
#     p = []
#     p.append(a[0])
#
#     for i in range(1, n):
#         if a[i] != p[-1]:
#             p.append(a[i])
#         elif b[i] != p[-1]:
#             p.append(b[i])
#         else:
#             p.append(c[i])
#
#     if p[-1] == p[0]:
#         if a[0] != p[-1]:
#             p[-1] = a[0]
# ...

# %%
for batch in batches:
    batch_responses = preprocessing(batch)  # Your `preprocessing` function
    responses.extend(batch_responses)
# Out:
# Error generating response for prompt: 0
# Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 4. Meaning that the model was reciting from copyrighted material.
# 1 done
# 2 done
# 3 done
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[87], line 2
#       1 for batch in batches:
# ----> 2     batch_responses = preprocessing(batch)  # Your `preprocessing` function
#       3     responses.extend(batch_responses)
#
# Cell In[83], line 9, in preprocessing(dataframe)
#       7 solution = row["solutions"]
#       8 try:
# ----> 9     generated_soln = model.generate_content(prompt)
#      10     responses.append(
#      11         {
#      12             "task_id": task_id,
#    (...)
#      16         }
# ...

# %% [markdown]
# ### Defining the model

# %%
from transformers import T5ForConditionalGeneration

model = T5ForConditionalGeneration.from_pretrained("Salesforce/codet5-base")
model.resize_token_embeddings(len(tokenizer))  # Resize embeddings if tokenizer changes

# %%
print(model.num_parameters())  # Optional: Check total parameters

# %% [markdown]
# ### FineTune With Trainer API

# %% [markdown]
# ### Save and Evaluate the Model
